# %%
from typing import Any, Union
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
from IPython.display import display
import pyMechkar as mechkar

# %%
desired_width=1000
#pd.set_option('display.width', desired_width)
#np.set_printoptions(linewidth=desired_width)
#pd.set_option('display.max_columns',18)

# %%
Data = pd.read_csv("final_csv1_full.csv", header=0)
#pd.options.display.max_columns = 13
#display(Data)
print(Data.head())
# Out:
#         Product   Customer  Product_Customer  Year  Month  Week  Quantity  \
# 0  7.290000e+12  416000134      7.290000e+21  2018      4    15       240
# 1  7.290000e+12  416000026      7.290000e+21  2018      4    16        48
# 2  3.796090e+05  416200105      3.800000e+14  2018      8    33        76
# 3  7.290000e+12  416200105      7.290000e+21  2018      8    35       176
# 4  7.290000e+12  416200105      7.290000e+21  2018      8    32        36
#
#    Avg_cost  Standart_price  below_Standart_Price  Above_Standart_Price  \
# 0     12.68           12.63                     0                     1
# 1      7.50            7.50                     0                     0
# 2      2.43            2.43                     0                     0
# 3      4.14            4.14                     0                     0
# 4      1.09            1.09                     0                     0
#
#    Category  Holiday  Temp_Hi  Temp_Lo  Temp_Rain
# 0    102939        1    23.43    14.57          1
# 1    100321        1    26.86    17.57          0
# 2    100405        0    31.57    24.29          0
# 3    100188        0    31.67    24.33          0
# 4    100221        0    32.00    25.14          0

# %%
Data.describe()
# Out:
#             Product      Customer  Product_Customer      Year          Month  \
# count  1.050930e+05  1.050930e+05      1.050930e+05  105093.0  105093.000000
# mean   6.813183e+12  4.160040e+08      6.813183e+21    2018.0       5.626464
# std    1.786314e+12  2.711995e+04      1.786314e+21       0.0       1.696180
# min    1.700000e+01  4.160000e+08      1.741600e+10    2018.0       3.000000
# 25%    7.290000e+12  4.160001e+08      7.290000e+21    2018.0       4.000000
# 50%    7.290000e+12  4.160001e+08      7.290000e+21    2018.0       6.000000
# 75%    7.290000e+12  4.160002e+08      7.290000e+21    2018.0       7.000000
# max    7.290000e+12  4.162001e+08      7.290000e+21    2018.0       8.000000
#
#                 Week       Quantity       Avg_cost  Standart_price  \
# count  105093.000000  105093.000000  105093.000000   105093.000000
# mean       22.854595      51.644800       6.035078        5.776777
# std         7.570899     173.882089      11.556218        5.498098
# min         9.000000       0.000000       0.000000        0.760000
# 25%        17.000000      12.000000       2.750000        2.770000
# 50%        23.000000      20.000000       4.020000        4.020000
# 75%        30.000000      48.000000       6.870000        6.870000
# max        36.000000   25424.000000     926.400000       30.880000
#
#        below_Standart_Price  Above_Standart_Price       Category  \
# count         105093.000000         105093.000000  105093.000000
# mean               0.098874              0.057473  100546.399656
# std                0.298495              0.232745     854.266755
# min                0.000000              0.000000  100188.000000
# 25%                0.000000              0.000000  100204.000000
# 50%                0.000000              0.000000  100222.000000
# 75%                0.000000              0.000000  100404.000000
# max                1.000000              1.000000  103560.000000
#
#              Holiday        Temp_Hi        Temp_Lo      Temp_Rain
# count  105093.000000  105093.000000  105093.000000  105093.000000
# mean        0.352745      29.533615      20.060633       0.076095
# std         0.477826       3.396528       4.391774       0.265151
# min         0.000000      21.570000      10.000000       0.000000
# 25%         0.000000      26.290000      17.570000       0.000000
# 50%         0.000000      31.430000      21.290000       0.000000
# 75%         1.000000      32.000000      24.140000       0.000000
# max         1.000000      34.000000      25.140000       1.000000

# %%
Data.dtypes
# Out:
# Product                 float64
# Customer                  int64
# Product_Customer        float64
# Year                      int64
# Month                     int64
# Week                      int64
# Quantity                  int64
# Avg_cost                float64
# Standart_price          float64
# below_Standart_Price      int64
# Above_Standart_Price      int64
# Category                  int64
# Holiday                   int64
# Temp_Hi                 float64
# Temp_Lo                 float64
# Temp_Rain                 int64
# dtype: object

# %%
Data.dtypes[Data.dtypes=='float64']
# Out:
# Product             float64
# Product_Customer    float64
# Avg_cost            float64
# Standart_price      float64
# Temp_Hi             float64
# Temp_Lo             float64
# dtype: object

# %%
## determine the number of missing values
Data.isna().sum()
# Out:
# Product                 0
# Customer                0
# Product_Customer        0
# Year                    0
# Month                   0
# Week                    0
# Quantity                0
# Avg_cost                0
# Standart_price          0
# below_Standart_Price    0
# Above_Standart_Price    0
# Category                0
# Holiday                 0
# Temp_Hi                 0
# Temp_Lo                 0
# Temp_Rain               0
# dtype: int64

# %%
## Ploting bivariate relationtips. This graph will show the scatterplot for each combination and at 
## the diagonal will show the histogram of the variable. This graph helps to detect correlations and 
## outliers
sns.pairplot(Data, height=2)
plt.show()
plt.savefig("output.png")

# %%
sns.boxplot(x=Data['Quantity'], y=Data['Product'])
plt.show()

# %%
Data2 = Data.copy()

# %%
Data2['class'] = Data2['Product_Customer'].astype('category')

# %%
sns.boxplot(x=Data2['Quantity'], y=Data2['Product_Customer'])
plt.show()

# %%
sns.distplot(Data['Temp_Hi'])
plt.show()

# %%
sns.distplot(Data['Temp_Lo'])
plt.show()

# %%
tab1=mechkar.pyMechkar().Table1(data=Data)
tab1
# Out:
# Factorizing... please wait
# [****************
# []
# ------ Finished in 2.492079496383667econds -----
#     Del             Variables    Categories  n  \
# 0     0           Individuals             n  1
# 1     0               Product     Mean (SD)  1
# 2     0               Product  Median (IQR)  2
# 3     1               Product   Missing (%)  3
# 4     0              Customer     Mean (SD)  1
# 5     0              Customer  Median (IQR)  2
# 6     1              Customer   Missing (%)  3
# 7     0      Product_Customer     Mean (SD)  1
# 8     0      Product_Customer  Median (IQR)  2
# 9     1      Product_Customer   Missing (%)  3
# 10    0                  Year          2018  0
# 11    0                 Month             8  0
# 12    0                 Month             7  1
# 13    0                 Month             5  2
# 14    0                 Month             4  3
# 15    0                 Month             6  4
# 16    0                 Month             3  5
# 17    0                  Week     Mean (SD)  1
# 18    0                  Week  Median (IQR)  2
# 19    1                  Week   Missing (%)  3
# 20    0              Quantity     Mean (SD)  1
# 21    0              Quantity  Median (IQR)  2
# 22    1              Quantity   Missing (%)  3
# 23    0              Avg_cost     Mean (SD)  1
# 24    0              Avg_cost  Median (IQR)  2
# 25    1              Avg_cost   Missing (%)  3
# 26    0        Standart_price     Mean (SD)  1
# 27    0        Standart_price  Median (IQR)  2
# 28    1        Standart_price   Missing (%)  3
# 29    1  below_Standart_Price             0  0
# 30    0  below_Standart_Price             1  1
# 31    1  Above_Standart_Price             0  0
# 32    0  Above_Standart_Price             1  1
# 33    0              Category     Mean (SD)  1
# 34    0              Category  Median (IQR)  2
# 35    1              Category   Missing (%)  3
# 36    1               Holiday             0  0
# 37    0               Holiday             1  1
# 38    0               Temp_Hi     Mean (SD)  1
# 39    0               Temp_Hi  Median (IQR)  2
# 40    1               Temp_Hi   Missing (%)  3
# 41    0               Temp_Lo     Mean (SD)  1
# 42    0               Temp_Lo  Median (IQR)  2
# 43    1               Temp_Lo   Missing (%)  3
# 44    1             Temp_Rain             0  0
# 45    0             Temp_Rain             1  1
#
#                                            Population
# 0                                              105093
# 1         6,813,183,322,705.60 (1,786,305,512,274.70)
# 2   7,290,000,000,000.00 (7,290,000,000,000.00-7,2...
# 3                                                 --
# 4                          416,003,972.50 (27,119.80)
# 5      416,000,102.00 (416,000,052.00-416,000,152.00)
# 6                                                 --
# 7   6,813,183,321,671,826,669,568.00 (1,786,305,51...
# 8   7,289,999,999,999,999,475,712.00 (7,289,999,99...
# 9                                                 --
# 10                             105,093.00 (  100.00%)
# 11                              14,615.00 (   13.90%)
# 12                              17,607.00 (   16.80%)
# 13                              18,253.00 (   17.40%)
# 14                              14,615.00 (   13.90%)
# 15                              17,607.00 (   16.80%)
# 16                              18,253.00 (   17.40%)
# 17                                   22.90 (    7.60)
# 18                          23.00 (   17.00-   30.00)
# 19                                                --
# 20                                   51.60 (  173.90)
# 21                          20.00 (   12.00-   48.00)
# 22                                                --
# 23                                    6.00 (   11.60)
# 24                           4.00 (    2.80-    6.90)
# 25                                                --
# 26                                    5.80 (    5.50)
# 27                           4.00 (    2.80-    6.90)
# 28                                                --
# 29                              94,702.00 (   90.10%)
# 30                              10,391.00 (    9.90%)
# 31                              99,053.00 (   94.30%)
# 32                               6,040.00 (    5.70%)
# 33                              100,546.40 (  854.30)
# 34                 100,222.00 (100,204.00-100,404.00)
# 35                                                --
# 36                              68,022.00 (   64.70%)
# 37                              37,071.00 (   35.30%)
# 38                                   29.50 (    3.40)
# 39                          31.40 (   26.30-   32.00)
# 40                                                --
# 41                                   20.10 (    4.40)
# 42                          21.30 (   17.60-   24.10)
# 43                                                --
# 44                              97,096.00 (   92.40%)
# 45                               7,997.00 (    7.60%)

# %%
mechkar.pyMechkar().exploreData(data=Data)
# Out:
# C:\Python\Anaconda3\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
